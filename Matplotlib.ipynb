# %% [markdown]
# ### 1 .Matplotib is an open-source visualization library for the python programming language.
# ### 2 .widely used for creating static,animated and interactive plots. It provides an object-oriented API for embedding plots inot applications using general-purpose GUI toolkits like YKinter,QL,GTK and wxPython

# %% [markdown]
# # ***creating Different Types of Plots***

# %% [markdown]
# ## 1 LIne Graph
# ### line graphs are commonly used to visualize trends over time or relationships between variables.We Will learn how to
# ### create visually appealing line graphs to represent such data

# %%
import matplotlib.pyplot as plt
x=[3,1,3]
y=[3,2,1]
plt.plot(x,y)
plt.title("Line Chart")
plt.legend(['Line'])
plt.show()

# %% [markdown]
# # 2. Bar chart
# ### A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and height
# ### that is proportional to the values which they represent. The bar plots can be plotted horizontally .A bar chart describes
# ### the comparisons between the discreate categories.It can be created using the bar() method.

# %%
import matplotlib.pyplot as plt
x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]
plt.bar(x,y)
plt.title('Bar Chart')
plt.legend(['bar'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # ***Plotting Histogram***
# ### Histogram is basically used to represent data in the form of some groups. it is a bar plot where the X-axis represents the
# ### bin ranges while  the y-axis gives information about frequency. To create a Histogram the first step is to create a bin of
# ### the ranges,then distributs the whole range of ht values into a series of intervals and count the values which fall inot each ofthe intervals. Bins are clearly identified as consecutive, non-overlapping intervals of variables.

# %%
import matplotlib.pyplot as plt 
x=[7,2,5,4,5]
plt.hist(x,bins=[1,2,4,5])
plt.title('Histogram')
plt.legend('bar')
plt.show()
