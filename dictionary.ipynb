# %% [markdown]
# # dictionaries

# %% [markdown]
# ### Defination: a dictionary is a mutable data type that maps unique,immutable keys to values.
#  # mutable can not work in key  work in value. = set,list

# %%
dec1={'course': "data science",'time': '10am','no.ofstd':100}
print(dec1)
# Out:
# {'course': 'data science', 'time': '10am', 'no.ofstd': 100}

# %%
course2={'course':'data analyst','timing':'11am','no.ofstd':100,'course':'data science'} 
print(course2)
# Out:
# {'course': 'data science', 'timing': '11am', 'no.ofstd': 100}

# %%
course3={'course1':'data analyst','timing':'11am','no.ofstd':100,'course':'data science'}
print(course3)
# Out:
# {'course1': 'data analyst', 'timing': '11am', 'no.ofstd': 100, 'course': 'data science'}

# %%
std={1:'mohit boura',2:"aksa"}
print(std)
# Out:
# {1: 'mohit boura', 2: 'aksa'}

# %%
innovators={[1,2]:'steve jobs',[3,4]:'elon musk'}
print(innovators)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 innovators={[1,2]:'steve jobs',[3,4]:'elon musk'}
#       2 print(innovators)
#
# TypeError: unhashable type: 'list'

# %%
innovators={(1,2):'steve jobs',(3,4):'elon musk'}
print(innovators) #mutable can not work in key  work in value.
# Out:
# {(1, 2): 'steve jobs', (3, 4): 'elon musk'}

# %%
innovators={{1,2}:'steve jobs',{3,4}:'elon musk'}
print(innovators) 
innovators[
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 innovators={{1,2}:'steve jobs',{3,4}:'elon musk'}
#       2 print(innovators)
#
# TypeError: unhashable type: 'set'

# %%
innovators={(1,2):'steve jobs',(3,4):'elon musk'}
print(innovators)
innovators[(1,2)]
# Out:
# {(1, 2): 'steve jobs', (3, 4): 'elon musk'}
# 'steve jobs'

# %%
innovators={{1:2}:'steve jobs',{3:4}:'elon musk'}
print(innovators)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 innovators={{1:2}:'steve jobs',{3:4}:'elon musk'}
#       2 print(innovators)
#
# TypeError: unhashable type: 'dict'

# %%
innovators={1:'elon',2:'mohit boura',3:'steve'}
print(innovators)
# Out:
# {1: 'elon', 2: 'mohit boura', 3: 'steve'}

# %%
value1={1:1,2:1,3:1}
print(value1)
# Out:
# {1: 1, 2: 1, 3: 1}

# %%
value2={1:[23],2:[12]}
print(value2)
# Out:
# {1: [23], 2: [12]}

# %%
soul1={2:{1},6:{'mohit boura'}}
print(soul1)
# Out:
# {2: {1}, 6: {'mohit boura'}}

# %%
soul1={2:{1},6:{'mohit boura'}}
soul1[2]
# Out:
# {1}

# %%
soul1={2:{1},'no.ofstu': 100}
print(id(soul1))
soul1['no.ofstu']=200
print(soul1)
print(id(soul1))
# Out:
# 2473572339968
# {2: {1}, 'no.ofstu': 200}
# 2473572339968

# %%
mohit_list1={3:2,2:'elon',1:[12] }
print(mohit_list1)
# Out:
# {3: 2, 2: 'elon', 1: [12]}

# %%
elone_1={1:'mohit boura',2:'setev'}
setev_1=set(elone_1.items())
print(setev_1)
# Out:
# {(2, 'setev'), (1, 'mohit boura')}

# %%
elone_1={1:'mohit boura',2:'setev'}
setev_1=set(elone_1.keys())
print(setev_1)
# Out:
# {1, 2}

# %%
elone_1={1:'mohit boura',2:'setev'}
setev_1=tuple(elone_1.items())
print(setev_1)
# Out:
# ((1, 'mohit boura'), (2, 'setev'))

# %%
elone_1={1:'mohit boura',2:'setev'}
setev_1=tuple(elone_1. values())
print(setev_1)
# Out:
# ('mohit boura', 'setev')

# %%
elone_1={1:'mohit boura',2:'setev'}
elone_1[1]='12'
print(elone_1)
# Out:
# {1: '12', 2: 'setev'}

# %%
value_1={1:'mohit boura',2:'elon','num':1000}
print(value_1)
print(type(value_1))
len(value_1)
# Out:
# {1: 'mohit boura', 2: 'elon', 'num': 1000}
# <class 'dict'>
# 3

# %%
value_1['num']=10
print(value_1)
# Out:
# {1: 'mohit boura', 2: 'elon', 'num': 10}

# %%
data1={(1):111,2:12233,'data2':10000,4:4}
data1['data']=12
print(data1)
# Out:
# {1: 111, 2: 12233, 'data2': 10000, 4: 4, 'data': 12}

# %%
data1={(1):111,2:12233,'data2':10000,4:4}
print(data1.keys())
# Out:
# dict_keys([1, 2, 'data2', 4])

# %%
data1={(1):111,2:12233,'data2':10000,4:4}
print(data1.values())
# Out:
# dict_values([111, 12233, 10000, 4])

# %%
data1={(1):111,2:12233,'data2':10000,4:4}
print(data1.items())
# Out:
# dict_items([(1, 111), (2, 12233), ('data2', 10000), (4, 4)])

# %%
zometo={'burger':99,10:'burger'}
print(zometo)
zometo['burger']=120
zometo[10]=5
print(zometo)
# Out:
# {'burger': 99, 10: 'burger'}
# {'burger': 120, 10: 5}

# %%
dict1={(1,):12,1:23}
print(dict1)
# Out:
# {(1,): 12, 1: 23}

# %%
data1={1:111,2:12233,'data2':10000,4:4}
print(data1.items())
# Out:
# dict_items([(1, 111), (2, 12233), ('data2', 10000), (4, 4)])

# %%
data1={(1):111,2:12233,'data2':10000,4:4}
print(data1.values())
# Out:
# dict_values([111, 12233, 10000, 4])

# %%
data2={1:12,34:(34,3)} 
print(data2)
# Out:
# {1: 12, 34: (34, 3)}

# %%
dict1={1111:(23),23:{23},34:[3],495:45}
print(dict1)
dict1.get(1111)
# Out:
# {1111: 23, 23: {23}, 34: [3], 495: 45}
# 23

# %%
d ={'name':'mohit','age':17}
print(d['name'])
print(d.get('age'))
# Out:
# mohit
# 17

# %%
dict1={1:23,'name':'mohit boura'}
print(dict1[1])
# Out:
# 23

# %%
print(dict1.get('name'))
# Out:
# mohit boura

# %%
print(d[2]) # indexing does not work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(d[2])
#
# KeyError: 2

# %%
dict1={1:2,'salary':1000000}
dict1.get('salary')
print(dict1['salary'])
# Out:
# 1000000

# %% [markdown]
#   # insert update

# %%
d={1:'mohit'}
print(d)
d[1]='boura'
print(d)
# Out:
# {1: 'mohit'}
# {1: 'boura'}

# %%
d1={1:'elon','salary':1000000}
d1.update({'salary':500000,1:'mohit'})
print(d1)
# Out:
# {1: 'mohit', 'salary': 500000}

# %%
data1={23:'mohit','job':'data' 'analyst'}

# %% [markdown]
# # pop()

# %%
d={'a':12,'b':13}
val=d.pop('a')
print('popped a:',val,"|d now:",d)
# Out:
# popped a: 12 |d now: {'b': 13}

# %%
like1={'1':23,334:34,3:{344}}
(like1.pop('1'))
print(like1)
# Out:
# {334: 34, 3: {344}}

# %%
like1.popitem()
print(like1)
# Out:
# {334: 34}

# %%
d={'a':12,'b':13}
val=d.pop('a')
print(d)
# Out:
# {'b': 13}

# %% [markdown]
# # popitems

# %%
 d={'x':12,'y':'mohit boura'}
item=d.popitem()
print('popped item:',item,'|d now:',d)
# Out:
# popped item: ('y', 'mohit boura') |d now: {'x': 12}

# %%
day={1:'mohit boura',2:'hello'}
day.popitem()
print(day)
# Out:
# {1: 'mohit boura'}

# %%
day={1:'mohit boura',2:'hello'}
day.update({1:'mohit',2:'elon',3:344})
print(day)
# Out:
# {1: 'mohit', 2: 'elon', 3: 344}

# %%
print(day.get(2))
print(day[2])
# Out:
# elon
# elon

# %% [markdown]
# # keys(), value(), items()

# %%
data1={'course1':'mohit boura',1:12}
print(data1.keys())
# Out:
# dict_keys(['course1', 1])

# %%
data1={'course1':'mohit boura',1:12}
print(data1.values())
# Out:
# dict_values(['mohit boura', 12])

# %%
data1={'course1':'mohit boura',1:12} # type casting dictionary to list, set , tuple
print(data1.items())
# Out:
# dict_items([('course1', 'mohit boura'), (1, 12)])

# %% [markdown]
#  #  type   casting

# %%
keys_1 = list(data1.keys()) # type casting dictionary to list, set , tuple
print(type(keys_1))
print(keys_1)
# Out:
# <class 'list'>
# ['course1', 1]

# %%
data_112=set(data1.items())
print(data_112)
# Out:
# {(1, 12), ('course1', 'mohit boura')}

# %%
data12=list(data1.values())
print(data12)
# Out:
# ['mohit boura', 12]

# %%
day1={1:'hek',2:'game',3:13}
print(day1.keys())
# Out:
# dict_keys([1, 2, 3])

# %%
data12=tuple(data1.values())
print(data12)
# Out:
# ('mohit boura', 12)

# %%
day1={1:'hek',2:'game',3:13}
print(day1.values())
day2= list(day1.values())
# Out:
# dict_values(['hek', 'game', 13])

# %%
day3=set(day1.keys())
print(day3)
# Out:
# {1, 2, 3}

# %%
day3=set(day1.items())
print(day3)
# Out:
# {(1, 'hek'), (3, 13), (2, 'game')}

# %%
day_1={1:12,'salary':1200000,'name':'mohit'}
print(day_1.get('salary'))
# Out:
# 1200000

# %%
print(day_1['salary'])
# Out:
# 1200000

# %%
print(day_1.update{1:23}
# Out:
#   Cell In[6], line 1
#     print(day_1.update{1:23})
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
day_1={1:12,'salary':1200000,'name':'mohit'}
day_1.update({1:13,2:'almora',3:'uttarakhand'})
print(day_1)
# Out:
# {1: 13, 'salary': 1200000, 'name': 'mohit', 2: 'almora', 3: 'uttarakhand'}

# %%
day_1={1:12,'salary':1200000,'name':'mohit'}
day_1.pop(1)
print(day_1)
# Out:
# {'salary': 1200000, 'name': 'mohit'}

# %%
day_1={1:12,'salary':1200000,'name':'mohit'}
day_1.popitem()
print(day_1)
# Out:
# {1: 12, 'salary': 1200000}

# %%
day1={1:243,'name':'mohit boura'}
day1['name']=[1]
print(day1)
# Out:
# {1: 243, 'name': [1]}

# %%
dict1={1:12,'name':12,'salary':111110}
dict1['salary']=133444
print(dict1)
# Out:
# {1: 12, 'name': 12, 'salary': 133444}

# %%
data1={1:'mohit boura',2:'mohit boura',3:'mohit boura'}
data1.update({2:'salary2x'})
print(data1)
# Out:
# {1: 'mohit boura', 2: 'salary2x', 3: 'mohit boura'}

# %%
data1={1:'mohit boura',2:'mohit boura',3:'mohit boura'}
data1.update({2:'salary2x'})
print(data1)
# Out:
# {1: 'mohit boura', 2: 'salary2x', 3: 'mohit boura'}

# %%
data1={} # empty
data1.update({2:'salary2x'})
print(data1)
data1[2]='salary4x'
print(data1)
# Out:
# {2: 'salary2x'}
# {2: 'salary4x'}

# %%
mohit_1={1:12,'mohit':'boura','data1':'1223'}
mohit_1.keys()
# Out:
# dict_keys([1, 'mohit', 'data1'])

# %%
mohit_1={1:12,'mohit':'boura','data1':'1223'}
mohit_1.values()
new_list1= list(mohit_1)
print(new_list1)
# Out:
# [1, 'mohit', 'data1']

# %%
mohit_1={1:12,'mohit':'boura','data1':'1223'}
mohit_1.items()
new_mohit=set(mohit_1.values())
print(new_mohit)
# Out:
# {'boura', '1223', 12}

# %%
new_chat={1:2,'name':'mohit','salary':1234}
wow= set(new_chat)
print(wow)
# Out:
# {1, 'name', 'salary'}

# %%
wow= tuple(new_chat)
print(wow)
# Out:
# (1, 'name', 'salary')

# %%
wow= str(new_chat)
print(id(wow))
print(wow)
print(id(wow))
print(type(wow))
# Out:
# 1905586731408
# {1: 2, 'name': 'mohit', 'salary': 1234}
# 1905586731408
# <class 'str'>

# %%
pop1={1:122,2:'mohit boura'}
pop1.pop(1)
print(pop1)
# Out:
# {2: 'mohit boura'}

# %%
wow= str(new_chat)
print(wow)
# Out:
# {1: 2, 'name': 'mohit', 'salary': 1234}

# %%
str1={1:'mohit boura',1:'mohit boura',12:122}
str1.update({1:'salary'})
print(str1)
str1[1]='salary2x'
print(str1)
# Out:
# {1: 'salary', 12: 122}
# {1: 'salary2x', 12: 122}

# %%
string={(1):{1},'course':12,'num':1234,'num':1233}
print(string)
len(string)
# Out:
# {1: {1}, 'course': 12, 'num': 1233}
# 3

# %%
string.get('course')
# Out:
# 12334

# %%
string['course']=12334
print(string)
# Out:
# {1: {1}, 'course': 12334, 'num': 1233}

# %%
for i in string:
    print(i)
# Out:
# 1
# course
# num

# %%
for i in string:
    print(string)
# Out:
# {1: {1}, 'course': 12334, 'num': 1233}
# {1: {1}, 'course': 12334, 'num': 1233}
# {1: {1}, 'course': 12334, 'num': 1233}

# %%
dict1={1:'mohit','name':'salary'}
sstr1=str(dict1)
print(sstr1)
print(type(sstr1))
# Out:
# {1: 'mohit', 'name': 'salary'}
# <class 'str'>

# %%
dict1={1:12,'mohit':'boura'}
dict1.get(1)
dict1.update({1:13,'mohit':12})
print(dict1)
# Out:
# {1: 13, 'mohit': 12}
# 1
# mohit

# %%
for i in dict1:
    print(i)
# Out:
# 1
# mohit
