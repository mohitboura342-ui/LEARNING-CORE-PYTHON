# %% [markdown]
# # get multiple inputs from a user in one line:use of split(),function

# %% [markdown]
# ### in python it is possible to get multiple values in one line. we can accept two or three values from the user.
# ### for example,in a single execution of the input () function we can ask the user his/her name,age and phone number and store it in three different
# ### variables.
# ### et see how to do this.
# ### take each input separated by space split input string using split() get the value of individual input
# ### here are few common use cases for split() function;
# ### (1) tokeninzeing a string ]: if you have a string that contains mulitiple words or value separated by a specific character
# ### (such as space,comma or anyother delimiter),you can use split() the string into individual tokens. for example.
#                   ### must be str or none,not int

# %%
amount=float(input('enter amount in words:'))
print(type(amount))
# Out:
# enter amount in words: 23
# <class 'float'>

# %%
amount=input('enter amount in digits:')

# %%
print(type(amount))

# %% [markdown]
# # the type of data from input function is always string.

# %%
amount1=float(input('enter amount in digits:'))
amount2=float(input('enter amount in digits:'))
print(amount1+amount2)
print(type(amount1))
# Out:
# enter amount in digits: 12
# enter amount in digits: 22
# 34.0
# <class 'float'>

# %%
amount1=int(input('enter amount in digits:'))
amount2=int(input('enter amount in digits:'))
print(amount1+amount2)
print(type(amount1))
# Out:
# enter amount in digits: 11
# enter amount in digits: 11
# 22
# <class 'int'>

# %% [markdown]
# # basic  calculater

# %%
num1= float(input('enter first number:'))
num2= float(input('enter second number:'))
result=num1+ num2
print(result)

# %%
num1 =float(input('enter first number'))
num2=float(input('enter second number'))
num1+num2
# Out:
# enter first number 12
# enter second number 12
# 24.0

# %%
num1=float(input('enter amount:'))
num2= float(input('enter second number:'))
if num1*num2>num1:
    print('good amount')
elif num1*num2<15:
     print('nice')
else:
    print('out of order')
# Out:
# enter amount: 1233
# enter second number: 1
# out of order

# %%
num1=float(input('enter amount:'))
num2= float(input('enter second number:'))
opt=

# %%
num1= int(input('enter first number:'))
num2= int(input('enter second number:'))
result=num1* num2
print(result)

# %%
num1= float(input('enter first number:'))
num2= float(input('enter second number:'))
result=num1/num2
print(result)
# Out:
# enter first number: 12
# enter second number: 222
# 0.05405405405405406

# %%
num2= float(input('salary'))
num1=float(input('salary'))
if num2!=1:
    print('yes')
else:
    print('not')
new_num=num2 +- num1
print(new_num)
print(new_num)
# Out:
# salary 12
# salary 12
# yes
# 0.0
# 0.0

# %%
number = input()
# Out:
#  10

# %%
num1 = input('enter a number')
# Out:
# enter a number 12

# %%
your_name = input ('fill up your name')
# Out:
# fill up your name mohit boura

# %%
x =3 
y=5
result=y*x
print(result)
# Out:
# 15

# %% [markdown]
# # conditional statements( if , else,elif)

# %%
num3 = input('name')

# %%
num2= float(input('salary'))
num1=float(input('salary'))
if num2!=1:
    print('yes')
else:
    print('not')
new_num=num2 +- num1
print(new_num)
print(new_num)
# Out:
# salary 1223
# salary 223
# yes
# 1000.0
# 1000.0

# %%
value1= float(input('number of student'))
value2= float(input('number of boys'))
operators= input ('operators  in use')
if  operators=='+':
    result=value1+value2
elif  operators =='-':
    result=value1-value2
elif operators =='*':
     result=value1*value2
elif operators=='%':
    result=value1%value2
else:
    print ('operators not found')

print(result)


print(type(result))
# Out:
# number of student 2
# number of boys 2
# operators  in use 2
# operators not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      12 else:
#      13     print ('operators not found')
# ---> 15 print(result)
#      18 print(type(result))
#
# NameError: name 'result' is not defined

# %%
value=int(input('age'))
value3=float(input('days'))
operators = input ('operators in use')
if operators=='+':
    result=value+value3
elif operators=='-':
        result=value-value3
elif operators=='*':
    result= value*value3
elif operators=='/':
        result=value/value3
elif operators=='<':
        result=value <value3
elif operators=='>':
        result=value>value3

else:
    print('not found operators')
    
print(result)
# Out:
# age 14
# days 333
# operators in use **
# not found operators
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 20
#      17 else:
#      18     print('not found operators')
# ---> 20 print(result)
#
# NameError: name 'result' is not defined

# %%
data1= int (input ('river in india'))
data2=float(input('village people in india'))
operators=input('operators in use')
if   operators=='+':
    total=data1+data2
if operators=='-':
        total=data1-data2
elif operators=='*':
        total=data1*data2
elif operators=='>':
    total=data1>data2
elif operators=='<':
        total=data1<data2
elif operators =='/':
    total=data1/data2
elif operators =='!=':
    total=data1!=data2

elif operators =='<=': 
    total=data1==data2
elif operators =='>=':
    total=data1>=data2
elif operators =='==':
    total=data1==data2 
    
else:
    print('operators not found')
print(total)    
print(type(total))
# Out:
# river in india 4
# village people in india 45
# operators in use *
# 180.0
# <class 'float'>

# %%
value1= float (input('years'))
value2= float(input('days'))
operators= input('operators in use')
if operators=='+':
    total=value1+value2
elif operators =='-':
    total=value1-value2
elif operators=='==':
    total=value1==value2
elif operators =='!=':
    total=value1 != value2
elif operators =='*':
    total=value1*value2
elif operators =='/':
    total=value1/value2
elif operators=='**':
    total=value1**value2
elif operators=='<=':
    total=value1<=value2
elif operators=='>=':
    total=value1>=value2
       
else:
    print('operators not found')

print(total)
print(type(total))
# Out:
# years 12
# days 2
# operators in use //
# operators not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 26
#      23 else:
#      24     print('operators not found')
# ---> 26 print(total)
#      27 print(type(total))
#
# NameError: name 'total' is not defined

# %%
name1=input('name')
print(name1)
# Out:
# name mohit
# mohit

# %%
value1=float(input('first num'))
value2=float(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2

else:
    print('not found')

print(number)
# Out:
# first num 12
# second num 2
# operators in use 2
# not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      13 else:
#      14     print('not found')
# ---> 16 print(number)
#
# NameError: name 'number' is not defined

# %% [markdown]
# ### value1=float(input('first1'))
# value2=float(input('second2'))
# operators = input('operators in use')
# if operators=='+':
#     num=value1+value2
# elif operators=='-':
#     num=value1-value2
# elif operators=='/':
#     num=value1-value2
# elif operators=='*':
#     num=value1*value2
# else:
#     print('operators are not found')
#
# print(num)

# %%
value1=float(input('first num'))
value2=float(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2
    print(number)
else:
    print('not found')
print(number)
# Out:
# first num 3
# second num 3
# operators in use ==
# not found
# 0.0

# %%
value1=float(input('first num'))
value2=float(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2
    
else:
    print('not found')
print(number)
# Out:
# first num 2
# second num 2
# operators in use --
# not found
# 0.0

# %%
value1=float(input('first num'))
value2=float(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2 
elif opt=='<=':
    number=value1<=value2
elif opt =='>=':
    number=value1>=value2
elif opt =='==':
    number=value1==value2
elif opt =='!=':
    number=value1!=value2
else:
    print('not found')
print(number)
# Out:
# first num 33
# second num 3
# operators in use //
# not found
# 14.0

# %% [markdown]
# # tea making

# %%
ing=input('ingredients in use')
if ing =='tea leave,lemon,water':
    result='lemon tea'
elif ing  =='milk, tea leave, ginger,water':
    result='milk tea'
elif ing =='milk,water tea leave,ginger,tea masala':
    result='masala tea'  
else:
    print('not found')
print(result)
# Out:
# ingredients in use tea leave,lemon,water
# lemon tea

# %%
value1=list(input('first num'))
value2=list(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2
    
else:
    print('not found')
print(number)
# Out:
# first num 2
# second num 23
# operators in use +
# ['2', '2', '3']

# %%
value1=set(input('first num'))
value2=set(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2
    
else:
    print('not found')
print(number)
# Out:
# first num 32
# second num 2
# operators in use -
# {'3'}

# %%
value1=dict(input('first num'))
value2=dict(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2
    
else:
    print('not found')
print(number)
# Out:
# first num 33:3,3:3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 value1=dict(input('first num'))
#       2 value2=dict(input('second num'))
#       3 opt =input ('operators in use')
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
value1=tuple(input('first num'))
value2=tuple(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2
    
else:
    print('not found')
print(number)
# Out:
# first num 12
# second num 23
# operators in use +
# ('1', '2', '2', '3')

# %% [markdown]
# # split()

# %%
mohit='hello,34,44'
mohit1=mohit.split('34')
print(mohit1)
# Out:
# ['hello,', ',44']

# %%
sentence = 'hello how are you today?'
words=sentence.split() # splitting by def
print(words)
print(type(words))
# Out:
# ['hello', 'how', 'are', 'you', 'today?']
# <class 'list'>

# %%
sentence = '10,2,3,3,3,3'
words=sentence.split(",") # splitteng by comma 
print(words)
print(type(words))
# Out:
# ['10', '2', '3', '3', '3', '3']
# <class 'list'>

# %%
sentence = 'hello how are you today?'
words=sentence.split('mohit')
print(words)
print(type(words))
# Out:
# ['hello how are you today?']
# <class 'list'>

# %%
sentence = 'hello how are you today?'
words=sentence.split(*)
print(words)
print(type(words))
# Out:
#   Cell In[19], line 2
#     words=sentence.split(*)
#                           ^
# SyntaxError: Invalid star expression

# %%
sentence = 'hello how are you today?'
words=sentence.split('*')
print(words)
print(type(words)) # use of striing
# Out:
# ['hello how are you today?']
# <class 'list'>

# %%
sentence = 'hello how are you today?'
words=sentence.split(12)
print(words)
print(type(words)) # must be str or none,not int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 sentence = 'hello how are you today?'
# ----> 2 words=sentence.split(12)
#       3 print(words)
#       4 print(type(words))
#
# TypeError: must be str or None, not int

# %% [markdown]
# ## extracting substrings

# %%
date ='2025*06*06'
year,month,day=date.split('*')
print(year,month,day)
# Out:
# 2025 06 06

# %%
date ='2025*06$ 23$ 033'
year,month,day=date.split('$')
print(year,month,day)
# Out:
# 2025*06  23  033

# %%
date ='2025* 6/ 23$ 33'
year,month,day=date.split('/')
print(year,month,day)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 date ='2025* 6/ 23$ 33'
# ----> 2 year,month,day=date.split('/')
#       3 print(year,month,day)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
date ='34;4445$ 34,44,4'
new_date=date.split(';')
print(new_date)
# Out:
# ['34', '4445$ 34,44,4']

# %%
date ='34;4445$ 34,44# ,4'
new_date=date.split('#')
print(new_date)
# Out:
# ['34;4445$ 34,44', ' ,4']

# %%
date ='34;4445$ 34,44@,4'
new_date=date.split('@')
print(new_date)
# Out:
# ['34;4445$ 34,44', ',4']

# %%
date ='34;4445$ 34,44,4'
new_date=date.split('34')
print(new_date)
# Out:
# ['', ';4445$ ', ',44,4']

# %% [markdown]
# ***(3) parsing data:***
# ### if you have a string repersentaion of structured data,such as CSV or tab-sparated values,you can use split() to separate the values and
# ### procces them  individually. for example

# %%
data='jhon,25,54,5'
name, data,day,no=data.split(',')
print(name,data,day,no)
# Out:
# jhon 25 54 5

# %%
data1='jhon,25,54,5'
name=data1.split(',')
print(name)
# Out:
# ['jhon', '25', '54', '5']

# %%
data1='jhon,25,54,5'
name=data1.split('jhon')
print(name)
# Out:
# ['', ',25,54,5']

# %%
data1='jhon,25,54,5'
name=data1.split('jhon,25,54,5')
print(name)
# Out:
# ['', '']

# %%
date=input('mohit 2333 boura')
name=set(date.split(','))
print(name)
print(type(name))
# Out:
# mohit 2333 boura mohit
# {'mohit'}
# <class 'set'>

# %% [markdown]
# # its important to note that split() returns a list of subsstring, and you can specify the delimiter as an argument to the function. if no deliniter
# ### is provided,it splits the string  by whitespace characters by default.

# %%
name,age,salary=input('enter your name,age,lpa separatedby $').split('$')
print(name,age,salary)
# Out:
# enter your name,age,lpa separatedby $ mohit$boura$12$
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 name,age,salary=input('enter your name,age,lpa separatedby $').split('$')
#       2 print(name,age,salary)
#
# ValueError: too many values to unpack (expected 3)

# %%
num1=input('enter three name').split(',')
# Out:
# enter three name 'mohit,boura,paras'

# %%
num1=input('enter three name').split()
# Out:
# enter three name mohit,paras,boura

# %%
num1=input('enter three name').split('*')
# Out:
# enter three name mohit*data analyst

# %%
num1=input('enter three name').split()
# Out:
# enter three name mohit,boura

# %%
int1=input('name of ingrident')
if  int1=='lemon leave,water,ginger':
    result='lemon tea'

elif int1=='ginger,milk,water,garm msala,kali mirch':
     result='masala tea'

elif int1=='ginger,milk,water':
     result='plan tea' 
else:
    print('not like a tea ingrident')
    
print(result)

# %%
tea=input('need')
print(ingrident)
if ingrident=='lemon leaves,water,ginger':

elif ingrident=='milk,water,ginger':
    need='tea'
elif ingrident=='ginger,milk,water,gram msala':
    need='msala tea'
else:
    print('not found')
print(need)
# Out:
#   Cell In[1], line 5
#     elif ingrident=='milk,water,ginger':
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
tea=input('tea ')
if ingrident=='lemon leaves water ginger':
    tea='lemon tea'
    price_of_tea='price=49'
elif ingrident=='tea leaves water milk':
    tea='plan tea'
    price_of_tea='price=29'
elif ingrident=='ginger milk water gram masala':
    tea='masala tea'
    price_of_tea='price=59'
elif ingrident== 'ginger kali mirch water':
    tea='plan tea without milk'
    price_of_tea='price=19'
elif ingrident=='lemon leaves water':
    tea='lemon tea without ginger'
    price_of_tea='price=35'
elif  ingrident=='milk water gram masala':
    tea= 'masala tea without ginger'
    price_of_tea='price=49'
else:  
    print('not available this items sorry')
print(tea)
print(price_of_tea)
print(ingrident)
print('wait for few minutes')
print('enjoy your drink')
# Out:
# tea  plan tea
# lemon tea
# price=49
# lemon leaves water ginger
# wait for few minutes
# enjoy your drink

# %%
tea=input('which tea you need ?')
if tea=='lemon tea':
    ingrident = 'lemon leves water ginger'
    price_of_tea = 'price=49'
elif tea== 'plan tea':
     ingrident='milk water tea leaves '
     price_of_tea='price=29'
elif tea=='masala tea':
    ingrident='milk water tea leaves kali mirch ginger '
    price_of_tea='price=59'
elif tea=='plan tea without milk':
    ingrident='ginger kali mirch water'
    price_of_tea='price=19'
elif tea=='lemon tea without ginger':
    ingrident='lemon leaves water '
    price_of_tea='price=35'
elif  tea=='masala tea without ginger':
      ingrident=' kali mirch water milk tea leaves'
      price_of_tea='price=49'
else:  
    print('NOT AVAILABLE THIS TIME SORRY') 
print('ingrident in use')
print(ingrident)
print(price_of_tea)
print('wait for few minutes ')
print('enjoy your tea')
# Out:
# which tea you need ? plan tea without milk
# ingrident in use
# ginger kali mirch water
# price=19
# wait for few minutes
# enjoy your tea

# %%
card=input('enter card name')
your_need=input('enter amount')
enter=input('enter pin')
if card=='SBI CREDIT CARD':
    your_need='chack amount'
    your_need='amount'
elif card=='UTTARAKHAND GRAMIN BANK CREDIT CARD':
    your_need='chack amount'
    your_need='enter amount'
elif card=='ICICI CREDIT CARD':
    your_need='chack amount'
    your_need='enter amount'

else:
    print('THIS CARD IS NOT VALID??')
print('wait?')

print('amount is credit form your card!')

print('transaction is done')
# Out:
# enter card name SBI CREDIT CARD
# enter amount 3445
# enter pin 67789
# wait?
# amount is credit form your card!
# transaction is done

# %%
data=input('age,name,phone number')
