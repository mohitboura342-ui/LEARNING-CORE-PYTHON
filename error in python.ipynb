# %%
1str='6741764,74,8848585,mohit boura'
print(1str)
# Out:
#   Cell In[1], line 1
#     1str='6741764,74,8848585,mohit boura'
#     ^
# SyntaxError: invalid decimal literal

# %%
my_list = [23,'mohit boura',34,22,[34]]
for '6' in my_list:
    print('6')
# Out:
#   Cell In[1], line 2
#     for '6' in my_list:
#         ^
# SyntaxError: cannot assign to literal

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
pop(2)
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 my_list=['mohit boura',13203,444,42,344,[42,324]]
# ----> 2 pop(2)
#       3 print(my_list)
#
# NameError: name 'pop' is not defined

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.clear(1:6)
print(my_list)
# Out:
#   Cell In[3], line 2
#     my_list.clear(1:6)
#                    ^
# SyntaxError: invalid syntax

# %%
list1=[1,2,3,4,5]
list2=[22,34,5,3]
list3=list1*list2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 list1=[1,2,3,4,5]
#       2 list2=[22,34,5,3]
# ----> 3 list3=list1*list2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
student_name=['mohit boura,paras,abhay,aman']
new_student=[]
new_student.insert(student_name)
print(new_student)|
# Out:
#   Cell In[1], line 4
#     print(new_student)|
#                        ^
# SyntaxError: invalid syntax

# %%
student_name=['mohit boura,paras,abhay,aman']
new_student=[]
new_student.reverse(student_name)
print(new_student)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 student_name=['mohit boura,paras,abhay,aman']
#       2 new_student=[]
# ----> 3 new_student.reverse(student_name)
#       4 print(new_student)
#
# TypeError: list.reverse() takes no arguments (1 given)

# %%
set={'mohit boura',36873,[23,323,23,23,33]} # list is unhashable
print(set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 set={'mohit boura',36873,[23,323,23,23,33]} # list is unhashable
#       2 print(set)
#
# TypeError: unhashable type: 'list'

# %%
set={3.3,3344,345,'mohit',(3),45,45} # index not work in set
set[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 set={3.3,3344,345,'mohit',(3),45,45} # index not work in set
# ----> 2 set[2]
#
# TypeError: 'set' object is not subscriptable

# %%
my_list=[44894,554,455,64,47]
set4= set(my_list)
print(set4)
# Out:
# {64, 455, 554, 47, 44894}

# %%
t = (4,56,566,555)#using operators
print(4 in t)
print(t in 4)
# Out:
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 t = (4,56,566,555)#using operators
#       2 print(4 in t)
# ----> 3 print(t in 4)
#
# TypeError: argument of type 'int' is not iterable

# %%
str=('mohit boura',344,344,43,4,34,390,334,3)
str.append(22)
print(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 str=('mohit boura',344,344,43,4,34,390,334,3)
# ----> 2 str.append(22)
#       3 print(str)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
list1=[11,32,34,4]
list2=[2,34,4,3,3]
print(list1-list2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 list1=[11,32,34,4]
#       2 list2=[2,34,4,3,3]
# ----> 3 print(list1-list2)
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
set1={'mohit boura','boura'}
set2={2,23,345,5,47}
set3=set1+set2
print(set3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 set1={'mohit boura','boura'}
#       2 set2={2,23,345,5,47}
# ----> 3 set3=set1+set2
#       4 print(set3)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
set1={'mohit boura','boura'}
set2={2,23,345,5,47}
set3=set2*set1
print(set3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 set1={'mohit boura','boura'}
#       2 set2={2,23,345,5,47}
# ----> 3 set3=set2*set1
#       4 print(set3)
#
# TypeError: unsupported operand type(s) for *: 'set' and 'set'

# %%
set1={'mohit boura','boura'}
set2={2,23,345,5,47}
set3=set2/set1
print(set3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 set1={'mohit boura','boura'}
#       2 set2={2,23,345,5,47}
# ----> 3 set3=set2/set1
#       4 print(set3)
#
# TypeError: unsupported operand type(s) for /: 'set' and 'set'

# %%
str1=('mohit boura',4,5,5)
str2=('mohit boura',(5,4))
str2.append(12)
print(str2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 str1=('mohit boura',4,5,5)
#       2 str2=('mohit boura',(5,4))
# ----> 3 str2.append(12)
#       4 print(str2)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
print(set2/tuple1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(set2/tuple1)
#
# NameError: name 'set2' is not defined

# %%
set6 ={1,2,3,45,6,33}
set3={234555,667,7,1,2,3,4}
set3.symmetricdifference(set6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 set6 ={1,2,3,45,6,33}
#       2 set3={234555,667,7,1,2,3,4}
# ----> 3 set3.symmetricdifference(set6)
#
# AttributeError: 'set' object has no attribute 'symmetricdifference'

# %%
string={{1}:{1},'course':12,'num':1234,'num':1233}
print(string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 string={{1}:{1},'course':12,'num':1234,'num':1233}
#       2 print(string)
#
# TypeError: unhashable type: 'set'

# %%
tea=input('need')
print(ingrident)
if ingrident=='lemon leaves,water,ginger':

elif ingrident=='milk,water,ginger':
    need='tea'
elif ingrident=='ginger,milk,water,gram msala':
    need='msala tea'
else:
    print('not found')
print(need)
# Out:
#   Cell In[1], line 5
#     elif ingrident=='milk,water,ginger':
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3
