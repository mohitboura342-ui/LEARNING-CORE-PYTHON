# %% [markdown]
# # A  tuple is an orderd, immutable collection.

# %% [raw]
#  allows duplicates
# good for fixed record

# %% [markdown]
# # creating tuples

# %%
str = (2,3,5)
print(type(str))
print(id(str))
# Out:
# <class 'tuple'>
# 2278059774336

# %%
list=(3,'mohit boura')
print(tuple(list))
# Out:
# (3, 'mohit boura')

# %%
list2=(3,)
print(tuple(list2))
# Out:
# (3,)

# %%
t2= 1,2,3
print(t2)
print(type(t2))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %%
t3=2,
print(type(t3))
print(t3)
# Out:
# <class 'tuple'>
# (2,)

# %% [markdown]
# # tuple  methods

# %% [markdown]
# # len()

# %%
str=(2,43,55,2)
len(str)
# Out:
# 4

# %% [markdown]
# # tuple. count()

# %%
t=(1,3,5,55,6,5,5,5,5,5,5,5)
t.add(2)
print(t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 t=(1,3,5,55,6,5,5,5,5,5,5,5)
# ----> 2 t.add(2)
#       3 print(t)
#
# AttributeError: 'tuple' object has no attribute 'add'

# %%
t = ('mohit boura', 'paras ')
t.count('mohit boura')
# Out:
# 1

# %%
t = ('mohit boura', 'paras ')
t.count('mohit')
# Out:
# 0

# %%
t = ('mohit boura', 'paras ')
len(t)
# Out:
# 2

# %% [markdown]
# # tuple.index()

# %%
 t =(1234,44.445,555,444,3)
t.index(555)
# Out:
# 2

# %% [markdown]
# # tuple slicing

# %%
 t =(1234,44.445,555,444,3)
t[1]
# Out:
# 44.445

# %%
tuple = (4,484,344,3894,34,4)
tuple[1:3]
# Out:
# (484, 344)

# %%
tuple1=(2,44,55,5,32424,'mohit')
tuple1[0:]
# Out:
# (2, 44, 55, 5, 32424, 'mohit')

# %% [markdown]
# # concatenation and reptition

# %%
t2 =(1,2)
t1 = (2,4)
print(t2+t1)
# Out:
# (1, 2, 2, 4)

# %%
t1*3
# Out:
# (2, 4, 2, 4, 2, 4)

# %%
print(t1+t2)
# Out:
# (2, 4, 1, 2)

# %%
tuple1=('mohit'   'boura'  )
print(tuple1*10)
# Out:
# mohitbouramohitbouramohitbouramohitbouramohitbouramohitbouramohitbouramohitbouramohitbouramohitboura

# %%
t=('mohit')
print(t*10)
# Out:
# mohitmohitmohitmohitmohitmohitmohitmohitmohitmohit

# %% [markdown]
# # membership operators

# %%
t = (4,56,566,555)#using operators
print(4 in t)
print(5 in t)
print(2 not in t)
# Out:
# True
# False
# True

# %%
t = (4,56,566,555)#using operators
print(4 in t)
print(t in 4)
# Out:
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 t = (4,56,566,555)#using operators
#       2 print(4 in t)
# ----> 3 print(t in 4)
#
# TypeError: argument of type 'int' is not iterable

# %%
name1= ('elon', 'sam')
name2 = ('mohit','boura',('elon','sam'))
print(name1 in name2)
print(name1 in name2)
print('elon'in name1)
print('sam'in name2)
print(name1[1] in name2)
# Out:
# True
# True
# True
# False
# False

# %%
print(name1 in name2)
# Out:
# True

# %%
name2 = ('mohit','boura',('elon','sam'))
print('sam' in name2)
# Out:
# False

# %%
name1 = [2,233,4,66,222,33,[33,34,45566,]]
print(34 in name1)
# Out:
# False

# %%
tuple=('mohit boura',344,94,748,'mohit boura',[632,2390,38])
print(type(tuple))
print(632 in tuple)
print([632,2390,38]  not in  tuple)
# Out:
# <class 'tuple'>
# False
# False

# %%
 str = ('mohit boura',23,3,44,5,43,3)
str2 = (94,67,7,6565,'mohit boura')
print(str[0] in str2)
# Out:
# True

# %%
str=('mohit boura',344,344,43,4,34,390,334,3)
str.count(344)
# Out:
# 2

# %%
str=('mohit boura',344,344,43,4,34,390,334,3)
str.index(43)
# Out:
# 3

# %%
str=('mohit boura',344,344,43,4,34,390,334,3)
str.append(22)
print(str)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 str=('mohit boura',344,344,43,4,34,390,334,3)
# ----> 2 str.append(22)
#       3 print(str)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple12=('mohit boura',34)
tuple2=('mohit boura',284,9303,23,334)
print(tuple12 in tuple2)
print(tuple2 not in tuple2)
# Out:
# False
# True

# %%
tuple12=('mohit boura')
tuple2=(284,9303,23,334,('mohit boura'))
print('mohit boura' in tuple2)
# Out:
# True

# %%
tuple=('mohit boura',12,2344,5,(23,344,'hello'))
print(tuple)
# Out:
# ('mohit boura', 12, 2344, 5, (23, 344, 'hello'))

# %%
tuple1=('mohit boura',23,94,494,3)
print(tuple1)
print(id(tuple1))
# Out:
# ('mohit boura', 23, 94, 494, 3)
# 2515999379504

# %%
str1=('mohit boura',4,5,5)
str2=('mohit boura',3,3,4,4)
print(str1[0] in str2)
# Out:
# True

# %%
str1=('mohit boura',4,5,5)
str2=('mohit boura',(5,4))
print(str1[0] in str2) 
print(str1[2]in str2)
# Out:
# True
# False

# %%
str1=('mohit boura',4,5,5)
str2=('mohit boura',(5,4))
print(str2)
# Out:
# ('mohit boura', (5, 4))

# %%
tuple1=(1,2,3,4,4,4,4,4)
tuple1.count(3)
# Out:
# 1

# %%
tuple1=(2.4,4,556666745,45,4,55,4,55)
print(len(tuple1))
tuple1.count(4)
# Out:
# 8
# 3

# %%
tuple1=(2.4,4,556666745,45,4,55,4,55)
tuple2=(1,24,5,6789)
new_tuple =tuple1+tuple2
print(new_tuple)
# Out:
# (2.4, 4, 556666745, 45, 4, 55, 4, 55, 1, 24, 5, 6789)

# %%
tuple1=(2.4,4,556666745,45,4,55,4,55)
tuple2=(1,24,5,6789)
new_tuple =tuple1+tuple2
print(new_tuple)

# %%
tuple1=(2.4,4,556666745,45,4,55,4,55)
tuple2=(1,24,5,6789)
new_tuple =tuple1-tuple2
print(new_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 tuple1=(2.4,4,556666745,45,4,55,4,55)
#       2 tuple2=(1,24,5,6789)
# ----> 3 new_tuple =tuple1-tuple2
#       4 print(new_tuple)
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'tuple'

# %%
tuple1=(2.4,4,556666745,45,4,55,4,55)
print(tuple1+10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 tuple1=(2.4,4,556666745,45,4,55,4,55)
# ----> 2 print(tuple1+10)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
tuple1=[2.4,4,556666745,45,4,55,4,55]
print(tuple1*2)
# Out:
# [2.4, 4, 556666745, 45, 4, 55, 4, 55, 2.4, 4, 556666745, 45, 4, 55, 4, 55]

# %%
tuple1={4,556666745,45,4,55,4,55}
print(tuple1*2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 tuple1={4,556666745,45,4,55,4,55}
# ----> 2 print(tuple1*2)
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
tuple=(12,3,4,4)
print(tuple[1]==3)
print(tuple)
# Out:
# True
# (12, 3, 4, 4)
