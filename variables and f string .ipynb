# %% [markdown]
# # variables

# %% [raw]
# 1.identifiers can be combination of uppercase and lowercase letter, digits or an underscore(_)
# so my variables,variable_1,variables_for_print all valid python identifiers.
# 2.an identifier can not start with a digit. so while variables1 is valid 1variables is not valid.
# 3.we can't use special symboles like !,@,#,%,$^ etc in our identifier.
# 4.identifier can be of any length.

# %%
variables1_for_that=4.6
print(variables1_for_that)
# Out:
# 4.6

# %%
str='mohit'
print(str)
# Out:
# mohit

# %%
str2='6741764,74,8848585,mohit boura'
print(str2)
# Out:
# 6741764,74,8848585,mohit boura

# %%
1str='6741764,74,8848585,mohit boura'
print(1str)
# Out:
#   Cell In[10], line 1
#     1str='6741764,74,8848585,mohit boura'
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # identifeir

# %%
my_num=1,2,3,22,121,1,11,223
print(id(my_num))
# Out:
# 1790366158064

# %%
value1=float(input('first num'))
value2=float(input('second num'))
opt =input ('operators in use')
if   opt=='+':
    number=value1+value2
elif opt=='-':
    number=value1-value2
elif opt=='*':
    number=value1*value2
elif opt=='/':
    number=value1/value2

else:
    print('not found')
print(number)

# %% [markdown]
# ###

# %% [markdown]
# ## F STRING ###

# %%
name='mohit'
age=17
print(f'my name is {name} and iam {age} year old')
# Out:
# my name is mohit and iam 17 year old

# %%
x=12
y=12
print(f'value of x is {x},value of y is {y}')
# Out:
# value of x is 12,value of y is 12
