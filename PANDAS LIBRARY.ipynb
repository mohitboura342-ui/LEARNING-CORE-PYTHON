# %%
import pandas as pd

# %% [markdown]
# ## Reading a .csv(comma separated values) file as a pandas Data frame

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # printing the  rows of the dataframe

# %%
df.head()  # printing 5 rows from dataframe
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(3) # printing 3 rows from dataframe
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.head(7) # printing 10 rows from datafram
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ## printing the last  rows of the dataframe

# %%
df.tail(4) # print last four rows
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # printing some statistics of your Data frame

# %%
df.describe() # this gives the summary statistics of your data frame
# count : number of non_missing values
# mean:
# std : standerd deviation 
# min: minimum value of  the column
# 25% : 25th percentile of the column
# 50%: 50 th percentile of the column
# 75%: 75th percentile of the column
# max
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['PassengerId'].max()
# Out:
# 891

# %%
df['PassengerId'].min()
# Out:
# 1

# %%
df['Name'].max()
# Out:
# 'van Melkebeke, Mr. Philemon'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # shows the datatypes , number of non_missing vlaues in your data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
## nan( not a number)= missing values

# %% [markdown]
# # selecting and viewing your data

# %%
 
df['Cabin']
df.head(886)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# selecting multiple columns
df[['Name','Age']].head(3)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0

# %%
df[['Age','Cabin']].tail(10)
# Out:
#       Age Cabin
# 881  33.0   NaN
# 882  22.0   NaN
# 883  28.0   NaN
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 887  19.0   B42
# 888   NaN   NaN
# 889  26.0  C148
# 890  32.0   NaN

# %%
df[['Age','Name']].tail(10)
# Out:
#       Age                                      Name
# 881  33.0                        Markun, Mr. Johann
# 882  22.0              Dahlberg, Miss. Gerda Ulrika
# 883  28.0             Banfield, Mr. Frederick James
# 884  25.0                    Sutehall, Mr. Henry Jr
# 885  39.0      Rice, Mrs. William (Margaret Norton)
# 886  27.0                     Montvila, Rev. Juozas
# 887  19.0              Graham, Miss. Margaret Edith
# 888   NaN  Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                     Behr, Mr. Karl Howell
# 890  32.0                       Dooley, Mr. Patrick

# %%
df[df['Age']<25]   #the dateset of below of 25 old age
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 0              1         0       3              Braund, Mr. Owen Harris
# 7              8         0       3       Palsson, Master. Gosta Leonard
# 9             10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3      Sandstrom, Miss. Marguerite Rut
# 12            13         0       3       Saundercock, Mr. William Henry
# ..           ...       ...     ...                                  ...
# 875          876         1       3     Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3        Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                 Petroff, Mr. Nedelio
# 882          883         0       3         Dahlberg, Miss. Gerda Ulrika
# 887          888         1       1         Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# ...

# %%
df[['Name','Sex','Cabin']]
# Out:
#                                                   Name     Sex Cabin
# 0                              Braund, Mr. Owen Harris    male   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   C85
# 2                               Heikkinen, Miss. Laina  female   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  C123
# 4                             Allen, Mr. William Henry    male   NaN
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male   NaN
# 887                       Graham, Miss. Margaret Edith  female   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  C148
# 890                                Dooley, Mr. Patrick    male   NaN
#
# [891 rows x 3 columns]

# %% [markdown]
# # Checking Missing values in the dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
for i in df:
    print('titel',i)
# Out:
# titel PassengerId
# titel Survived
# titel Pclass
# titel Name
# titel Sex
# titel SibSp
# titel Parch
# titel Ticket
# titel Fare
# titel Cabin
# titel Embarked

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000  512.329200

# %%
# Out:
#       Name    Age
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 886  False  False
# 887  False  False
# 888  False  False
# 889  False  False
# 890  False  False
#
# [891 rows x 2 columns]

# %%
df.index[-12]
# Out:
# 879

# %%
df.index[-13]
# Out:
# 878

# %% [markdown]
# # Renaming columns in your dataframe

# %%
df.rename(columns={'PassengerId': 'So.No.'})
# Out:
#      So.No.  Survived  Pclass  \
# 0         1         0       3
# 1         2         1       1
# 2         3         1       3
# 3         4         1       1
# 4         5         0       3
# ..      ...       ...     ...
# 886     887         0       2
# 887     888         1       1
# 888     889         0       3
# 889     890         1       1
# 890     891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# ...

# %%
df.drop(columns=['Age'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.rename(columns={'Name':'Bhai Log'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Bhai Log     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={'So.No':'bhai log'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={'Age':'How_many_old_are'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns={'PassengerId':'So.No'},inplace=True)

# %%
df
# Out:
#      So.No  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# df

# %% [markdown]
# # filtering and Sorting

# %%
df[df['Age']>25]
# Out:
#      So.No  Survived  Pclass  \
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# 6        7         0       1
# ..     ...       ...     ...
# 883    884         0       2
# 885    886         0       3
# 886    887         0       2
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Age']>25) & (df['Sex']=='male')]
# Out:
#      So.No  Survived  Pclass                           Name   Sex   Age  \
# 4        5         0       3       Allen, Mr. William Henry  male  35.0
# 6        7         0       1        McCarthy, Mr. Timothy J  male  54.0
# 13      14         0       3    Andersson, Mr. Anders Johan  male  39.0
# 20      21         0       2           Fynney, Mr. Joseph J  male  35.0
# 21      22         1       2          Beesley, Mr. Lawrence  male  34.0
# ..     ...       ...     ...                            ...   ...   ...
# 881    882         0       3             Markun, Mr. Johann  male  33.0
# 883    884         0       2  Banfield, Mr. Frederick James  male  28.0
# 886    887         0       2          Montvila, Rev. Juozas  male  27.0
# 889    890         1       1          Behr, Mr. Karl Howell  male  26.0
# 890    891         0       3            Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[(df["Age"]<25) | (df['Sex']=='male')]
# Out:
#      So.No  Survived  Pclass                            Name     Sex   Age  \
# 0        1         0       3         Braund, Mr. Owen Harris    male  22.0
# 4        5         0       3        Allen, Mr. William Henry    male  35.0
# 5        6         0       3                Moran, Mr. James    male   NaN
# 6        7         0       1         McCarthy, Mr. Timothy J    male  54.0
# 7        8         0       3  Palsson, Master. Gosta Leonard    male   2.0
# ..     ...       ...     ...                             ...     ...   ...
# 884    885         0       3          Sutehall, Mr. Henry Jr    male  25.0
# 886    887         0       2           Montvila, Rev. Juozas    male  27.0
# 887    888         1       1    Graham, Miss. Margaret Edith  female  19.0
# 889    890         1       1           Behr, Mr. Karl Howell    male  26.0
# 890    891         0       3             Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch           Ticket     Fare Cabin Embarked
# ...

# %%
df[(df['Age']>50) & (df['Sex']=='male')] [['Name','Age','Sex','Survived']]
# Out:
#                                      Name   Age   Sex  Survived
# 6                 McCarthy, Mr. Timothy J  54.0  male         0
# 33                  Wheadon, Mr. Edward H  66.0  male         0
# 54         Ostby, Mr. Engelhart Cornelius  65.0  male         0
# 94                      Coxon, Mr. Daniel  59.0  male         0
# 96              Goldschmidt, Mr. George B  71.0  male         0
# 116                  Connors, Mr. Patrick  70.5  male         0
# 124           White, Mr. Percival Wayland  54.0  male         0
# 150            Bateman, Rev. Robert James  51.0  male         0
# 152                      Meo, Mr. Alfonzo  55.5  male         0
# 155           Williams, Mr. Charles Duane  51.0  male         0
# 170             Van der hoef, Mr. Wyckoff  61.0  male         0
# 174               Smith, Mr. James Clinch  56.0  male         0
# 222               Green, Mr. George Henry  51.0  male         0
# 232             Sjostedt, Mr. Ernst Adolf  59.0  male         0
# ...

# %%
df.sort_values('Age',ascending=False)
# Out:
#      So.No  Survived  Pclass                                      Name  \
# 630    631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851    852         0       3                       Svensson, Mr. Johan
# 493    494         0       1                   Artagaveytia, Mr. Ramon
# 96      97         0       1                 Goldschmidt, Mr. George B
# 116    117         0       3                      Connors, Mr. Patrick
# ..     ...       ...     ...                                       ...
# 859    860         0       3                          Razi, Mr. Raihed
# 863    864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868    869         0       3               van Melkebeke, Mr. Philemon
# 878    879         0       3                        Laleff, Mr. Kristo
# 888    889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %%
df[df['Name']=='Razi, Mr. Raihed']
# Out:
#      PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 859          860         0       3  Razi, Mr. Raihed  male  NaN      0      0
#
#     Ticket    Fare Cabin Embarked
# 859   2629  7.2292   NaN        C

# %%
df[df['Name']=='Barkworth, Mr. Algernon Henry Wilson']
# Out:
#      So.No  Survived  Pclass                                  Name   Sex  \
# 630    631         1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  80.0      0      0  27042  30.0   A23        S

# %%
df[df['Age']<25] [['Name','Sex','Ticket']]
# Out:
#                                     Name     Sex     Ticket
# 0                Braund, Mr. Owen Harris    male  A/5 21171
# 7         Palsson, Master. Gosta Leonard    male     349909
# 9    Nasser, Mrs. Nicholas (Adele Achem)  female     237736
# 10       Sandstrom, Miss. Marguerite Rut  female    PP 9549
# 12        Saundercock, Mr. William Henry    male  A/5. 2151
# ..                                   ...     ...        ...
# 875     Najib, Miss. Adele Kiamie "Jane"  female       2667
# 876        Gustafsson, Mr. Alfred Ossian    male       7534
# 877                 Petroff, Mr. Nedelio    male     349212
# 882         Dahlberg, Miss. Gerda Ulrika  female       7552
# 887         Graham, Miss. Margaret Edith  female     112053
#
# [278 rows x 3 columns]

# %%
df[df["Age"]==61] #61 years old passenger's dataset
# Out:
#      So.No  Survived  Pclass                       Name   Sex   Age  SibSp  \
# 170    171         0       1  Van der hoef, Mr. Wyckoff  male  61.0      0
# 326    327         0       3  Nysveen, Mr. Johan Hansen  male  61.0      0
# 625    626         0       1      Sutton, Mr. Frederick  male  61.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 170      0  111240  33.5000   B19        S
# 326      0  345364   6.2375   NaN        S
# 625      0   36963  32.3208   D50        S

# %%
df[df['Age']==12] #12 year old boy  dataset
# Out:
#      So.No  Survived  Pclass                          Name   Sex   Age  SibSp  \
# 125    126         1       3  Nicola-Yarred, Master. Elias  male  12.0      1
#
#      Parch Ticket     Fare Cabin Embarked
# 125      0   2651  11.2417   NaN        C

# %%
df{}

# %% [markdown]
# # Dropping  colums in your Dataframe

# %%
df.drop(columns=['Embarked','Cabin'])

# %%
df

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df

# %% [markdown]
# # Chacking the number of Unique values in a colums

# %%
# this gives you unique categories
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Sex.nunique()
# Out:
# 2

# %%
df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.Name.nunique() #how many name in data frame
# Out:
# 891

# %%
df.Age.nunique()
# Out:
# 88

# %%
df
# Out:
#      So.No  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Survived.unique()
# Out:
# array([0, 1])

# %%
df.Survived.nunique()
# Out:
# 2

# %%
df.rename(columns={'Age':'hello'})
# Out:
#      So.No  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex  hello  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male   35.0      0
# ..                                                 ...     ...    ...    ...
# ...

# %%
df[df["Cabin"]=='B42'] # cabin nuber B42  dateset
# Out:
#      So.No  Survived  Pclass                          Name     Sex   Age  \
# 887    888         1       1  Graham, Miss. Margaret Edith  female  19.0
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked
# 887      0      0  112053  30.0   B42        S

# %% [markdown]
# # cheking the categories

# %%
df.Sex.value_counts() # to counts how many time same values avilable in dataset
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.Age.value_counts() # this gives you the number of rows of each categories
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.Sex.value_counts() # number of male female
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Cabin.value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df.Name.value_counts()
# Out:
# Name
# Dooley, Mr. Patrick                                    1
# Braund, Mr. Owen Harris                                1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
#                                                       ..
# Uruchurtu, Don. Manuel E                               1
# Spencer, Mrs. William Augustus (Marie Eugenie)         1
# Glynn, Miss. Mary Agatha                               1
# Wheadon, Mr. Edward H                                  1
# Meyer, Mr. Edgar Joseph                                1
# Name: count, Length: 891, dtype: int64

# %%
df.Age.value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.Name.value_counts()
# Out:
# Name
# Dooley, Mr. Patrick                                    1
# Braund, Mr. Owen Harris                                1
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    1
# Heikkinen, Miss. Laina                                 1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1
#                                                       ..
# Uruchurtu, Don. Manuel E                               1
# Spencer, Mrs. William Augustus (Marie Eugenie)         1
# Glynn, Miss. Mary Agatha                               1
# Wheadon, Mr. Edward H                                  1
# Meyer, Mr. Edgar Joseph                                1
# Name: count, Length: 891, dtype: int64

# %% [markdown]
# # Creating a new column

# %%
df.['  ']

# %%
df
# Out:
#      So.No  Survived  Pclass  \
# 0        1         0       3
# 1        2         1       1
# 2        3         1       3
# 3        4         1       1
# 4        5         0       3
# ..     ...       ...     ...
# 886    887         0       2
# 887    888         1       1
# 888    889         0       3
# 889    890         1       1
# 890    891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
range_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 range_df
#
# NameError: name 'range_df' is not defined

# %%
import pandas as pd
data=pd.read_csv('people_data.csv')
data
# Out:
#   First Name Last Name     Sex                       Email Date of birth  \
# 0     Shelby   Terrell    Male        elijah57@example.net    1945-10-26
# 1    Phillip   Summers  Female       bethany14@example.com    1910-03-24
# 2   Kristine    Travis    Male       bthompson@example.com    1992-07-02
# 3    Yesenia  Martinez    Male   kaitlinkaiser@example.com    2017-08-03
# 4       Lori      Todd    Male  buchananmanuel@example.net    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
data.head(1)
# Out:
#   First Name Last Name   Sex                 Email Date of birth  \
# 0     Shelby   Terrell  Male  elijah57@example.net    1945-10-26
#
#          Job Title
# 0  Games developer

# %%
import numpy as np
import pandas as pd
n={'Name':['mohit','aadi','abhay'],
  'Age':[18,18,18],
   'village': ['Naulakot','Naulakot','Naulakot']}
data=pd.Series(n)
data
# Out:
# Name                 [mohit, aadi, abhay]
# Age                          [18, 18, 18]
# village    [Naulakot, Naulakot, Naulakot]
# dtype: object

# %%
import numpy as np
import pandas as pd
n={'Name':['mohit','aadi','abhay'],
  'Age':[18,19,18],
   'village': ['Naulakot','Naulakot','Naulakot']}
data=pd.DataFrame(n)
data
# Out:
#     Name  Age   village
# 0  mohit   18  Naulakot
# 1   aadi   19  Naulakot
# 2  abhay   18  Naulakot

# %%
import pandas as pf
import numpy as np
j={'Name':['navin','Abhay','yuvi',],
   'Age':[49,18,18],
  'village':['Naulakot(par)','Naulakot','Naulakot',],
  'Father_Name':['bala bubu','Mohit','Mohit',]}
data=pf.DataFrame(j)
data
# Out:
#     Name  Age        village Father_Name
# 0  navin   49  Naulakot(par)   bala bubu
# 1  Abhay   18       Naulakot       Mohit
# 2   yuvi   18       Naulakot       Mohit

# %%
data.Name  # to print name column
# Out:
# 0    Mohit Boura
# 1          Abhay
# 2           yuvi
# 3          nitin
# Name: Name, dtype: object

# %%
data.iloc[1]  # to print
# Out:
# Name              Abhay
# Age                  18
# village        Naulakot
# Father_Name       Mohit
# Name: 1, dtype: object
