# %% [raw]
# . there are two types  of data one is  mutable and other one is immutable.

# %% [markdown]
# # mutable data type:

# %% [markdown]
# list = 1
# set  = 2
# dictionary  = 3

# %% [markdown]
# # list(mutable/unhashable/sequence data type):-

# %% [raw]
# . it is a mutable data type having following characterstics
# . it contains duplicate items.
# . it can be modified,replaced or deleted without changing memory addressed.
# .  list is orderd  that is the order of the element is based in such a waythat they can be edit in some order.
# . the items of the list can be accessed directy using their index number and the index number starts from zero .
# . the list may contains mixed type of data
# . []reprsent the list
# .the list can  contian duplicates that is can have tso items with the same values.
# . list is iterable

# %% [markdown]
# # creating python list with different data type.

# %% [markdown]
# #### the list can be useing either the list construtor or using squara brackets.

# %%
list1 = 2324,5,3,
tapule1=2,34,45,
str1= 'mohit boura'
list2=list[tapule1]
print(list2)
# Out:
# list[2, 34, 45]

# %%
set1={2,3283.393303,393,1,1,1,1}
list1=272,292,292,22,
list2=set(set1)
print(set1)
# Out:
# {393, 2, 3283.393303, 1}

# %%
list3 = 2324,5,3,
tapule1=2,34,45,
str1= 'mohit boura'

# %%
list2=list[str1]
print(list2)
# Out:
# list['mohit boura']

# %% [markdown]
# # indexing

# %% [markdown]
# # list is orderd how accessing of a list (indexing shows the property of list being orderd

# %% [markdown]
# . the items in a list can be accessed through indexing and slicing . this secion will guide you be accessing the list using the following two ways.
# . using indexing, we can access any items from a list using its index number.
# . using slicling,we an access a renge of items from a list.

# %%
list=[32434,[2,2],23,33,'mohit',2]
len(list)
list[3]
# Out:
# 33

# %%
list[3]
# Out:
# 33

# %%
list[-1]
# Out:
# 2

# %% [markdown]
# # slicing

# %%
list=[32434,[2,2],23,33,'mohit',2]
list[0:2]
# Out:
# [32434, [2, 2]]

# %%
list=[32434,[2,2],23,33,'mohit',2]
list[0:]
# Out:
# [32434, [2, 2], 23, 33, 'mohit', 2]

# %%
list=[32434,[2,2],23,33,'mohit',2]
list[1:3]
# Out:
# [[2, 2], 23]

# %%
list=[32434,[2,2],23,33,'mohit',2]
print(id(list))
# Out:
# 2710344127552

# %%
list=[32434,[2,2],23,33,'mohit',2]
list[1:3]
print(id(list))
# Out:
# 2710369410624

# %%
list1=[1,2,34344,45]
list1[1:]
# Out:
# [2, 34344, 45]

# %% [markdown]
# # iterating a list.

# %% [raw]
# .the objects in the list can be iterated over one by using a for loop.

# %%
my_list = [23,'mohit boura',34,22,[34]]
for y in my_list:
    print(y)
# Out:
# 23
# mohit boura
# 34
# 22
# [34]

# %%
my_list = [23,'mohit boura',34,22,[34]]
for '6' in my_list:
    print('6')
# Out:
#   Cell In[12], line 2
#     for '6' in my_list:
#         ^
# SyntaxError: cannot assign to literal

# %%
my_list = [23,'mohit boura',34,22,[34]]
for t in my_list:
  print(t)
# Out:
# 23
# mohit boura
# 34
# 22
# [34]

# %% [markdown]
# # adding elemants to  the list.

# %% [markdown]
# # append

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.append('mohit boura')
print(list1)
# Out:
# [12, 8222, 29303, 303, 98, 'mohitboura', 'mohit boura']

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.append(3)
print(list1)
# Out:
# [12, 8222, 29303, 303, 98, 'mohitboura', 3]

# %% [markdown]
# # extend

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.extend('mohit boura')
print(list1)
# Out:
# [12, 8222, 29303, 303, 98, 'mohitboura', 'm', 'o', 'h', 'i', 't', ' ', 'b', 'o', 'u', 'r', 'a']

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.append(['mohit boura'])
print(list1)
# Out:
# [12, 8222, 29303, 303, 98, 'mohitboura', ['mohit boura']]

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.append(['mohit boura',39303])
print(list1)
# Out:
# [12, 8222, 29303, 303, 98, 'mohitboura', ['mohit boura', 39303]]

# %% [markdown]
# # insert

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.insert(0,['mohit boura',485,49503,8485955,49595])
print(list1)
# Out:
# [['mohit boura', 485, 49503, 8485955, 49595], 12, 8222, 29303, 303, 98, 'mohitboura']

# %%
list1 = [12,8222,29303,303,98,'mohitboura']
list1.insert(-0,'mohit boura')
print(list1)
# Out:
# ['mohit boura', 12, 8222, 29303, 303, 98, 'mohitboura']

# %% [markdown]
# # removing elements from list

# %% [raw]
# 1  remove(items)    to remove the first occurrence of the items from list.
# 2  pop(index)        remove and returns the items at the given index from the list.
# 3  clear()    to remove all items from the list. the output will be an empty list .
# 4  del list_name  delete the entire list.

# %% [markdown]
# # removing

# %%
my_list=['mohit boura',13203,444,344,42,324]
my_list.remove(42)
print(my_list)
# Out:
# ['mohit boura', 13203, 444, 344, 324]

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.remove(42)
print(my_list)
# Out:
# ['mohit boura', 13203, 444, 344, [42, 324]]

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.remove('mohit boura')
print(my_list)
# Out:
# [13203, 444, 42, 344, [42, 324]]

# %% [markdown]
# # pop(index)

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
pop(2)
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 my_list=['mohit boura',13203,444,42,344,[42,324]]
# ----> 2 pop(2)
#       3 print(my_list)
#
# NameError: name 'pop' is not defined

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.pop(2)
print(my_list)
# Out:
# ['mohit boura', 13203, 42, 344, [42, 324]]

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.pop(3)
print(my_list)
# Out:
# ['mohit boura', 13203, 444, 344, [42, 324]]

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.clear()
print(my_list)
# Out:
# []

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.clear()
print(my_list)
# Out:
# []

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
del my_list

# %% [markdown]
# # reverseing the list

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.reverse()
print(my_list)
# Out:
# [[42, 324], 344, 42, 444, 13203, 'mohit boura']

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.reverse()
print(my_list)
# Out:
# [[42, 324], 344, 42, 444, 13203, 'mohit boura']

# %%
my_list=['mohit boura',13203,444,42,344,[42,324]]
my_list.reverse
print(my_list)
# Out:
# ['mohit boura', 13203, 444, 42, 344, [42, 324]]

# %%
list_my=[253,8784,3939,333,3]
list_my.reverse()
print(list_my)
# Out:
# [3, 333, 3939, 8784, 253]

# %%
print(id(my_list))
# Out:
# 2913864552640

# %%
my_list=[112,47874,4304]
del my_list
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 my_list=[112,47874,4304]
#       2 del my_list
# ----> 3 print(my_list)
#
# NameError: name 'my_list' is not defined

# %%
list1=[1,4,3,5[4,5]]
lis
new_list=list1
print(new_list)
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_11656\7034569.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   list1=[1,4,3,5[4,5]]
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_11656\7034569.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   list1=[1,4,3,5[4,5]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 list1=[1,4,3,5[4,5]]
#       2 lis
#       3 new_list=list1
#
# TypeError: 'int' object is not subscriptable

# %%
list1=[6272,3,4,5,5]
new_list=[]
new_list.append(list1)
print(new_list)
# Out:
# [[6272, 3, 4, 5, 5]]

# %%
list1=[6272,3,4,5,5]
new_list=[]
new_list.extend(list1)
print(new_list)
# Out:
# [6272, 3, 4, 5, 5]

# %%
list1=[6272,3,4,5,5]
new_list=[]
new_list.extend(list1)
print(new_list)
# Out:
# [6272, 3, 4, 5, 5]

# %% [markdown]
# # concatenation of two lists
# the concatenation of two list means merging of two lists.there are two ways to do that.
# using the+operators . using the extend() method.the extend() method appends the new lists items at the ends of the calling list.

# %%
my_list1=[1,2,3]
my_list2=[4,5,6]
my_list1.extend(my_list2)
print(my_list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1=[1,2,3,4,5]
list2=[22,34,5,3]
list3=list1*list2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 list1=[1,2,3,4,5]
#       2 list2=[22,34,5,3]
# ----> 3 list3=list1*list2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
sum=[2,4,5,3,4]
sum2=[8229]
sum2.extend(sum)
print(sum2)
# Out:
# [8229, 2, 4, 5, 3, 4]

# %%
list1=[1,2,3,4,5]
list2=[22,34,5,3]
list1.extend(list2)
print(list2)
# Out:
# [22, 34, 5, 3]

# %%
list0=[23,4,2,3,32]
my_list33=[]
my_list33.extend(list0)
print(my_list33)
# Out:
# [23, 4, 2, 3, 32]

# %%
list0=[23,4,2,3,32]
my_list33=[]
my_list33.append(list0)
print(my_list33)
# Out:
# [[23, 4, 2, 3, 32]]

# %%
STR=['mohti boura']
str2=[]
str2.append(STR)
print(str2)
# Out:
# [['mohti boura']]

# %%
list_for=[3434,23,44,4,4,43]
list45=[]
list45.append(list_for)
print(list45)
# Out:
# [[3434, 23, 44, 4, 4, 43]]

# %%
list_hello=[74,'mohti boura',22,23,33,0]
list_hello.remove(22)
print(list_hello)
# Out:
# [74, 'mohti boura', 23, 33, 0]

# %%
list_hello=[74,'mohti boura',22,23,33,0]
list_hello.pop(2)
print(list_hello)
# Out:
# [74, 'mohti boura', 23, 33, 0]

# %%
list_hello=[74,'mohti boura',22,23,33,0]
list_hello.clear()
print(list_hello)
# Out:
# []

# %%
list_hello=[74,'mohti boura',22,23,33,0]
del list_hello

# %%
student_name=['mohit boura,paras,abhay,aman']
new_student=[]
new_student.extend(student_name)
print(new_student)
# Out:
# ['mohit boura,paras,abhay,aman']

# %%
student_name=['mohit boura,paras,abhay,aman']
new_student=[]
new_student.insert(student_name)
print(new_student)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 student_name=['mohit boura,paras,abhay,aman']
#       2 new_student=[]
# ----> 3 new_student.insert(student_name)
#       4 print(new_student)
#
# TypeError: insert expected 2 arguments, got 1

# %%
student_name=['mohit boura,paras,abhay,aman']
new_student=[]
new_student.append(student_name)
print(new_student)
# Out:
# [['mohit boura,paras,abhay,aman']]

# %%
list=[3,4,45,4,4,3]
print(id(list))
list[1]=3
print(list)
print(id(list))
# Out:
# 2036903685760
# [3, 3, 45, 4, 4, 3]
# 2036903685760

# %%
'hello'+' '+'world'
# Out:
# 'hello world'

# %%
num1=[85,556,67,56]
num2=[2,3,4,45,5]
# Out:
# False

# %%
x=18
y=18
print(x==y)
print(x is  y)
# Out:
# True
# True

# %% [raw]
# #idntifier

# %%
x=18
print(id(x))
y=18
print(id(y))
print(x==y)
print(x is  y)
# Out:
# 140708388713928
# 140708388713928
# True
# True

# %%
x=[18]   
print(id(x))
y=[18]
print(id(y))
print(x==y)
print(x is  y)
# Out:
# 1707658459456
# 1707658457600
# True
# False

# %%
nums1=[1,2,34,4,3]
nums1.reverse()
print(nums1)
# Out:
# [3, 4, 34, 2, 1]

# %%
nums1=[1,2,34,4,3]
nums1.pop((-1,-2,-3,-4,-5))
print(nums1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 nums1=[1,2,34,4,3]
# ----> 2 nums1.pop((-1,-2,-3,-4,-5))
#       3 print(nums1)
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
list2=[]
list2.extend('mohit boura')
print(list2)
# Out:
# ['m', 'o', 'h', 'i', 't', ' ', 'b', 'o', 'u', 'r', 'a']

# %%
nums1=[44,46,6,652,36636]
for t in nums1:
    print(t)
# Out:
# 44
# 46
# 6
# 652
# 36636

# %%
list1=[2]
print(id(list1))
list2=[2]
print(list1==list2)
print(id(list2))
print(list1 is list2)
# Out:
# 1998207623168
# True
# 1998207622976
# False

# %%
a = 49
num_list=[1,2,3]
a in num_list
# Out:
# False

# %%
a = 1
num_list=[1,2,3]
a in num_list
# Out:
# True

# %%
a = 1
num_list=[1,2,3] 
num_list in a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 a = 1
#       2 num_list=[1,2,3]
# ----> 3 num_list in a
#
# TypeError: argument of type 'int' is not iterable

# %%
 v =234
my_set={94,44940,404,849,234}
v is my_set
# Out:
# False

# %%
list='mohit boura'
list.endswith('oura')
# Out:
# True

# %%
list1=[2,35,5,65,6,5[45,65,6]]
print(45 in list1)
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_12052\2403034816.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   list1=[2,35,5,65,6,5[45,65,6]]
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_12052\2403034816.py:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   list1=[2,35,5,65,6,5[45,65,6]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 list1=[2,35,5,65,6,5[45,65,6]]
#       2 print(45 in list1)
#
# TypeError: 'int' object is not subscriptable

# %%
[1,2,3,45,3]+[3,45,2]
# Out:
# [1, 2, 3, 45, 3, 3, 45, 2]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 set={'mohit boura',239,0,3,2,3,'mohit boura'}
#       2 list1=[]
# ----> 3 list1.apeend(set)
#       4 print(list1)
#
# AttributeError: 'list' object has no attribute 'apeend'

# %%
name1 = [2,233,4,66,222,33,[33,34,45566,]]
print(34 in name1)
# Out:
# False

# %%
tuple1=(2,33,3,3,3,33,3,'mohit boura')
set={}
set.append(tuple1)
print(set)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 tuple1=(2,33,3,3,3,33,3,'mohit boura')
#       2 set={}
# ----> 3 set.append(tuple1)
#       4 print(set)
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
list1=[1,2,3,4,4,4,4]
del list1
print(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 list1=[1,2,3,4,4,4,4]
#       2 del list1
# ----> 3 print(list1)
#
# NameError: name 'list1' is not defined

# %%
list1=[1,2,3,'mohit','salary']
list1.append(12)
print(list1)
# Out:
# [1, 2, 3, 'mohit', 'salary', 12]

# %% [markdown]
# # list comperhension
