# %% [markdown]
# # python functions
# ### python functions are a block ###

# %%
def multiply():
   return num3=
# Out:
#   Cell In[15], line 2
#     return (num3=num1*num2)
#             ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
multiply(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 multiply(1,2)
#
# TypeError: multiply() takes 0 positional arguments but 2 were given

# %%
def add():
    return(1,2,3,4,3)

print(type(add))
# Out:
# <class 'function'>

# %%
add()
# Out:
# (1, 2, 3, 4, 3)

# %%
def new(): 
    return[2,3,4,'mohit']
new()
# Out:
# [2, 3, 4, 'mohit']

# %%
print(type(new))
# Out:
# <class 'function'>

# %%
def list1():
    return(1,2,4,5)

# %%
list1()
# Out:
# (1, 2, 4, 5)

# %%
def calculater(x,z):
    return(x+z)

# %%
calculater(2,4)
# Out:
# 6

# %%
def list():
    print([1,2,3,5,6])

# %%
list()
print(len(list))
# Out:
# [1, 2, 3, 5, 6]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 list()
# ----> 2 print(len(list))
#
# TypeError: object of type 'function' has no len()

# %%
def func(x,y):
    print(x-y)

# %%
func(1,23)
# Out:
# -22
